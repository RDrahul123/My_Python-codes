# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
X = np.array([[1], [2], [3], [4], [5]])
y = np.array([0, 0, 1, 1, 1])

# %%
model = LinearRegression()
model.fit(X, y)
predictions = model.predict(X)
print("Predictions:", predictions)
# Out:
# Predictions: [-1.11022302e-16  3.00000000e-01  6.00000000e-01  9.00000000e-01
#   1.20000000e+00]

# %%
print(mean_squared_error(y, predictions))
# Out:
# 0.06000000000000002

# %%
plt.scatter(X, y, color='Green', label='Actual data')
plt.plot(X, predictions, color='red', label='Linear Regression')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear Regression Fit')
# Out:
# Text(0.5, 1.0, 'Linear Regression Fit')

# %%
tf1= tf.constant([[1, 2], [3, 4]])
tf2 = tf.constant([[5, 6], [7, 8]])

tf3= tf.concat([tf1, tf2], axis=0)
print("Concatenated result:\n", tf3)
print("Concatenated result:\n", tf3.dtype)
# Out:
# Concatenated result:
#  tf.Tensor(
# [[1 2]
#  [3 4]
#  [5 6]
#  [7 8]], shape=(4, 2), dtype=int32)
# Concatenated result:
#  <dtype: 'int32'>
