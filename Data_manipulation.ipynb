# %% [markdown]
# # Importing all Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Extraction

# %%
read_data= pd.read_csv('Cryptocurrency Transaction Data.csv')

# %%
# print(read_dataframe.head())    # Display the first 5 rows of the DataFrame
print(read_data.info())    # Display the information about the DataFrame
# print(read_dataframe.describe())    # Display the summary statistics of the DataFrame
# print(read_dataframe.columns)    # Display the column names of the DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Transaction_ID      50000 non-null  object
#  1   Sender_Address      50000 non-null  object
#  2   Receiver_Address    50000 non-null  object
#  3   Amount              50000 non-null  float64
#  4   Transaction_Fee     50000 non-null  float64
#  5   Timestamp           50000 non-null  object
#  6   Block_ID            50000 non-null  object
#  7   Mining_Pool         50000 non-null  object
#  8   Currency            50000 non-null  object
#  9   Transaction_Type    50000 non-null  object
#  10  Transaction_Status  50000 non-null  object
#  11  Gas_Price_Gwei      25012 non-null  float64
# dtypes: float64(3), object(9)
# memory usage: 4.6+ MB
# None

# %% [markdown]
# # Data cleaning
#
# ### There are many null and duplicate values in this file. Hence before training the model we need to clean this data.

# %%
read_dataframe= read_data.isnull().sum()    # Check for missing values in the DataFrame
read_dataframe1= read_data.fillna(0, inplace=True)    # Fill missing values with 0
read_dataframe2= read_data.dropna()    # Drop rows with missing values
# print(read_dataframe.isnull().sum())    # Check for missing values again
# print(read_dataframe['Transaction Date'].unique())    # Display unique transaction dates

# %%
read_dataframe2.duplicated().sum()    # Check for duplicate rows in the DataFrame
# Out:
# 0

# %%
read_dataframe2
# Out:
#        Transaction_ID                              Sender_Address  \
# 0      TX2QW62Q5XM17K  0xd377b9203ad74038664c08f658c0245632651f55
# 1      TXQLO0O0OTW4LJ  0x82f88633d0181ac75ddf2a30e0536715323c36bb
# 2      TXUQHLOGH29HUX  0x3df47b281761298334f39e351a37135e366e00bc
# 3      TXOUB0QDRACX9V  0x048ec0b0375c05d8232374bee7cbf9d962003916
# 4      TXITZPHD2NENA7  0x5cd4d3cc6a2f410a350c0d3ad929ec1a2f4c32f5
# ...               ...                                         ...
# 49995  TX0X443B13GFTH  0xf87953bc787bc0caac74e60ca538e03c693ffd36
# 49996  TX0M9MRH5EV5X9  0x703a7224c9db46afc40ba76c3ee71a5c7f5025be
# 49997  TXDTFRPVODDOPF  0x6de2de190d098fa796a2ba6c0e727d87a272f58c
# 49998  TXQCIJD85AATA5  0x23933d8d350752b443a0ca7a3c6843bdb36c2506
# 49999  TXKOZMZ4M6L5SN  0x8da796a20603a765ad5020c1891b2de1305d687b
#
#                                  Receiver_Address     Amount  Transaction_Fee  \
# 0      0x4a3370c0f0b83d519ddf50892d006f64d7425880  11.396181         0.000062
# 1      0x7faeb5aa2b3c1d34bbe742dbf58a9405677983ce   9.504004         0.000043
# 2              3cwt5fdejoeo52pjyayfwvyufulihttiqs   1.814056         0.000199
# 3              367olmymnss867abmhfqdw9u2p4uxrcuer   4.759595         0.000704
# 4      0xe166fa006fd6b7d427d19e7e28c9338ab40cd273  12.333792         0.000273
# ...                                           ...        ...              ...
# 49995       bc1qqjt84qs94q5r83ev4d2uivsj6egumdi4a   8.958880         0.000413
# 49996          37pv34eo94t9bizvxvx9v3g52lbi2evnla  12.393886         0.000768
# 49997       bc1qhlxqkfxyagcd6ogoibfmfmdicipnf4i2u   9.369263         0.000733
# 49998  0x1e0c2894234b9e1d69462809ff7c15fb056a2879   2.655088         0.000260
# 49999          1vdbxp96zvr9lmsnv7qabkqtainob9dvhu  12.413572         0.000573
#
#                          Timestamp                  Block_ID Mining_Pool  \
# 0      2025-03-30T23:32:40.589676Z  f4A4D894b9Ee166B3F75F4Fb   Ethermine
# 1      2025-03-09T17:41:40.589676Z  9dDdFb5D8EfE8f162cadBd5a   Ethermine
# 2      2025-05-10T22:33:40.589676Z  29da64FB8ba86DBfE3c9fFD6     BTC.TOP
# 3      2025-03-29T19:07:40.589676Z  81e422afbc4DE8bFbf0266E2      Poolin
# 4      2025-03-05T08:29:40.589676Z  C1B27A9583D7FB3Aa5A7e140   Ethermine
# ...                            ...                       ...         ...
# 49995  2025-05-09T01:52:41.727213Z  CfaAeAA94f3BebF9eFCcd16A     Antpool
# 49996  2025-05-10T22:21:41.727213Z  8Ff1a4AAC4B3bBd6F4bbC31E  Slush Pool
# 49997  2025-05-09T01:33:41.727213Z  CcFC13Af2A727BbA5Affd4fE   Ethermine
# 49998  2025-04-11T03:01:41.727213Z  fb5ccdcfbbfD1d9a7061Da31   Ethermine
# 49999  2025-04-12T11:33:41.727213Z  cD8dcD29DCfC0bDdfe9f2e71      Poolin
#
#       Currency Transaction_Type Transaction_Status  Gas_Price_Gwei
# 0          ETH         Transfer          Confirmed            50.0
# 1          ETH         Transfer          Confirmed            25.0
# 2          BTC         Transfer          Confirmed             0.0
# 3          BTC         Transfer          Confirmed             0.0
# 4          ETH         Transfer          Confirmed            50.0
# ...        ...              ...                ...             ...
# 49995      BTC         Transfer          Confirmed             0.0
# 49996      BTC         Transfer          Confirmed             0.0
# 49997      BTC         Transfer          Confirmed             0.0
# 49998      ETH         Transfer          Confirmed            10.0
# 49999      BTC         Transfer          Confirmed             0.0
#
# [50000 rows x 12 columns]

# %%
read_dataframe2.to_csv('output2.csv', index= False)
